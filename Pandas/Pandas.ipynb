# %% [markdown]
# # Class - 1

# %% [markdown]
# ## Importing Pandas

# %%
import pandas as pd

# %% [markdown]
# ## Making DataFrame

# %%
pd.DataFrame({'Name':['Anik', 'Abir'], 'Roll':[11809018, 11809078]})
# Out:
#    Name      Roll
# 0  Anik  11809018
# 1  Abir  11809078

# %% [markdown]
# ## Making DataFrame with Index

# %%
pd.DataFrame({'Name':['Anik', 'Abir'], 'Roll':[11809018, 11809078]}, index=['p1','p2'])
# Out:
#     Name      Roll
# p1  Anik  11809018
# p2  Abir  11809078

# %% [markdown]
# ## Making Series

# %%
pd.Series([1,2,3,4,5])
# Out:
# 0    1
# 1    2
# 2    3
# 3    4
# 4    5
# dtype: int64

# %% [markdown]
# ## Series with Index

# %%
pd.Series([1,2,3,4,5],index=['p1','p2','p3','p4','p5'])
# Out:
# p1    1
# p2    2
# p3    3
# p4    4
# p5    5
# dtype: int64

# %% [markdown]
# ## Importing File

# %%
test = pd.read_csv('pokemon_data.csv')

# %% [markdown]
# ### Finding Shape

# %%
test.shape
# Out:
# (800, 12)

# %% [markdown]
# ### Showing Dataset using Head Function

# %%
test.head()
# Out:
#    #                   Name Type 1  Type 2  HP  Attack  Defense  Sp. Atk  \
# 0  1              Bulbasaur  Grass  Poison  45      49       49       65
# 1  2                Ivysaur  Grass  Poison  60      62       63       80
# 2  3               Venusaur  Grass  Poison  80      82       83      100
# 3  3  VenusaurMega Venusaur  Grass  Poison  80     100      123      122
# 4  4             Charmander   Fire     NaN  39      52       43       60
#
#    Sp. Def  Speed  Generation  Legendary
# 0       65     45           1      False
# 1       80     60           1      False
# 2      100     80           1      False
# 3      120     80           1      False
# 4       50     65           1      False

# %% [markdown]
# ### Don't Want another Index (CSV File has Index)

# %%
test = pd.read_csv('pokemon_data.csv', index_col=0)
test.head()
# Out:
#                     Name Type 1  Type 2  HP  Attack  Defense  Sp. Atk  \
# #
# 1              Bulbasaur  Grass  Poison  45      49       49       65
# 2                Ivysaur  Grass  Poison  60      62       63       80
# 3               Venusaur  Grass  Poison  80      82       83      100
# 3  VenusaurMega Venusaur  Grass  Poison  80     100      123      122
# 4             Charmander   Fire     NaN  39      52       43       60
#
#    Sp. Def  Speed  Generation  Legendary
# #
# 1       65     45           1      False
# 2       80     60           1      False
# 3      100     80           1      False
# 3      120     80           1      False
# 4       50     65           1      False

# %% [markdown]
# ## Accesing Column

# %%
test.Name
# Out:
# #
# 1                  Bulbasaur
# 2                    Ivysaur
# 3                   Venusaur
# 3      VenusaurMega Venusaur
# 4                 Charmander
#                ...
# 719                  Diancie
# 719      DiancieMega Diancie
# 720      HoopaHoopa Confined
# 720       HoopaHoopa Unbound
# 721                Volcanion
# Name: Name, Length: 800, dtype: object

# %% [markdown]
# ## Accesing Column 1

# %%
test['Name']
# Out:
# #
# 1                  Bulbasaur
# 2                    Ivysaur
# 3                   Venusaur
# 3      VenusaurMega Venusaur
# 4                 Charmander
#                ...
# 719                  Diancie
# 719      DiancieMega Diancie
# 720      HoopaHoopa Confined
# 720       HoopaHoopa Unbound
# 721                Volcanion
# Name: Name, Length: 800, dtype: object

# %% [markdown]
# ### Accesing First value of Column 1

# %%
test['Name'][1]
# Out:
# 'Bulbasaur'

# %% [markdown]
# ## Index - Based Seclection
# ##### Both loc and iloc are row-first, column-second. This is the opposite of what we do in native Python, which is column-first, row-second
# ## First Row

# %%
test.iloc[0]
# Out:
# Name          Bulbasaur
# Type 1            Grass
# Type 2           Poison
# HP                   45
# Attack               49
# Defense              49
# Sp. Atk              65
# Sp. Def              65
# Speed                45
# Generation            1
# Legendary         False
# Name: 1, dtype: object

# %% [markdown]
# ## First Column

# %%
test.iloc[:,0]
# Out:
# #
# 1                  Bulbasaur
# 2                    Ivysaur
# 3                   Venusaur
# 3      VenusaurMega Venusaur
# 4                 Charmander
#                ...
# 719                  Diancie
# 719      DiancieMega Diancie
# 720      HoopaHoopa Confined
# 720       HoopaHoopa Unbound
# 721                Volcanion
# Name: Name, Length: 800, dtype: object

# %% [markdown]
# ### Five Rows in First column

# %%
test.iloc[:5,0]
# Out:
# #
# 1                Bulbasaur
# 2                  Ivysaur
# 3                 Venusaur
# 3    VenusaurMega Venusaur
# 4               Charmander
# Name: Name, dtype: object

# %% [markdown]
# ### Accesing by using List

# %%
test.iloc[[0,1,2,3],0]
# Out:
# #
# 1                Bulbasaur
# 2                  Ivysaur
# 3                 Venusaur
# 3    VenusaurMega Venusaur
# Name: Name, dtype: object

# %% [markdown]
# ### Accesing last 5 records

# %%
test.iloc[-5:]
# Out:
#                     Name   Type 1 Type 2  HP  Attack  Defense  Sp. Atk  \
# #
# 719              Diancie     Rock  Fairy  50     100      150      100
# 719  DiancieMega Diancie     Rock  Fairy  50     160      110      160
# 720  HoopaHoopa Confined  Psychic  Ghost  80     110       60      150
# 720   HoopaHoopa Unbound  Psychic   Dark  80     160       60      170
# 721            Volcanion     Fire  Water  80     110      120      130
#
#      Sp. Def  Speed  Generation  Legendary
# #
# 719      150     50           6       True
# 719      110    110           6       True
# 720      130     70           6       True
# 720      130     80           6       True
# 721       90     70           6       True

# %% [markdown]
# # Class - 2

# %% [markdown]
# ## Label-based selection
# #### iloc is conceptually simpler than loc because it ignores the dataset's indices. When we use iloc we treat the dataset like a big matrix (a list of lists), one that we have to index into by position. loc, by contrast, uses the information in the indices to do its work. Since your dataset usually has meaningful indices, it's usually easier to do things using loc instead
# #### In this case df.iloc[0:1000] will return 1000 entries, while df.loc[0:1000] return 1001 of them! To get 1000 elements using loc, you will need to go one lower and ask for df.loc[0:999]

# %%
test.loc[1,'Name']
# Out:
# 'Bulbasaur'

# %% [markdown]
# ### Accesing using Name

# %%
test.loc[:,['Name', 'Defense', 'Speed']]
# Out:
#                       Name  Defense  Speed
# #
# 1                Bulbasaur       49     45
# 2                  Ivysaur       63     60
# 3                 Venusaur       83     80
# 3    VenusaurMega Venusaur      123     80
# 4               Charmander       43     65
# ..                     ...      ...    ...
# 719                Diancie      150     50
# 719    DiancieMega Diancie      110    110
# 720    HoopaHoopa Confined       60     70
# 720     HoopaHoopa Unbound       60     80
# 721              Volcanion      120     70
#
# [800 rows x 3 columns]

# %% [markdown]
# ## Manipulating Index

# %%
test.set_index('Name')
# Out:
#                         Type 1  Type 2  HP  Attack  Defense  Sp. Atk  Sp. Def  \
# Name
# Bulbasaur                Grass  Poison  45      49       49       65       65
# Ivysaur                  Grass  Poison  60      62       63       80       80
# Venusaur                 Grass  Poison  80      82       83      100      100
# VenusaurMega Venusaur    Grass  Poison  80     100      123      122      120
# Charmander                Fire     NaN  39      52       43       60       50
# ...                        ...     ...  ..     ...      ...      ...      ...
# Diancie                   Rock   Fairy  50     100      150      100      150
# DiancieMega Diancie       Rock   Fairy  50     160      110      160      110
# HoopaHoopa Confined    Psychic   Ghost  80     110       60      150      130
# HoopaHoopa Unbound     Psychic    Dark  80     160       60      170      130
# Volcanion                 Fire   Water  80     110      120      130       90
#
# ...

# %% [markdown]
# ## Conditional Selection

# %%
test=pd.read_csv('pokemon_data.csv',index_col=0)
test.Name == 'Venusaur'
# Out:
# #
# 1      False
# 2      False
# 3       True
# 3      False
# 4      False
#        ...
# 719    False
# 719    False
# 720    False
# 720    False
# 721    False
# Name: Name, Length: 800, dtype: bool

# %% [markdown]
# ## Selecting the Records

# %%
test.loc[test.Name == 'Venusaur']
# Out:
#        Name Type 1  Type 2  HP  Attack  Defense  Sp. Atk  Sp. Def  Speed  \
# #
# 3  Venusaur  Grass  Poison  80      82       83      100      100     80
#
#    Generation  Legendary
# #
# 3           1      False

# %% [markdown]
# ### Using &(and) operator

# %%
test.loc[(test.Defense >=80) & (test.HP >= 80)]
# Out:
#                       Name  Type 1  Type 2   HP  Attack  Defense  Sp. Atk  \
# #
# 3                 Venusaur   Grass  Poison   80      82       83      100
# 3    VenusaurMega Venusaur   Grass  Poison   80     100      123      122
# 18     PidgeotMega Pidgeot  Normal  Flying   83      80       80      135
# 31               Nidoqueen  Poison  Ground   90      92       87       75
# 59                Arcanine    Fire     NaN   90     110       80      100
# ..                     ...     ...     ...  ...     ...      ...      ...
# 715                Noivern  Flying  Dragon   85      70       80       97
# 716                Xerneas   Fairy     NaN  126     131       95      131
# 717                Yveltal    Dark  Flying  126     131       95      131
# 718       Zygarde50% Forme  Dragon  Ground  108     100      121       81
# 721              Volcanion    Fire   Water   80     110      120      130
#
#      Sp. Def  Speed  Generation  Legendary
# #
# ...

# %% [markdown]
# ### Using |(or) Operator

# %%
test.loc[(test['Type 2'] == 'Poison') | (test.HP >= 80)]
# Out:
#                       Name   Type 1  Type 2   HP  Attack  Defense  Sp. Atk  \
# #
# 1                Bulbasaur    Grass  Poison   45      49       49       65
# 2                  Ivysaur    Grass  Poison   60      62       63       80
# 3                 Venusaur    Grass  Poison   80      82       83      100
# 3    VenusaurMega Venusaur    Grass  Poison   80     100      123      122
# 13                  Weedle      Bug  Poison   40      35       30       20
# ..                     ...      ...     ...  ...     ...      ...      ...
# 717                Yveltal     Dark  Flying  126     131       95      131
# 718       Zygarde50% Forme   Dragon  Ground  108     100      121       81
# 720    HoopaHoopa Confined  Psychic   Ghost   80     110       60      150
# 720     HoopaHoopa Unbound  Psychic    Dark   80     160       60      170
# 721              Volcanion     Fire   Water   80     110      120      130
#
#      Sp. Def  Speed  Generation  Legendary
# #
# ...

# %% [markdown]
# ### Using isin Function

# %%
test.loc[test['Type 2'].isin(['Poison', 'Fairy'])].head(10)
# Out:
#                      Name  Type 1  Type 2   HP  Attack  Defense  Sp. Atk  \
# #
# 1               Bulbasaur   Grass  Poison   45      49       49       65
# 2                 Ivysaur   Grass  Poison   60      62       63       80
# 3                Venusaur   Grass  Poison   80      82       83      100
# 3   VenusaurMega Venusaur   Grass  Poison   80     100      123      122
# 13                 Weedle     Bug  Poison   40      35       30       20
# 14                 Kakuna     Bug  Poison   45      25       50       25
# 15               Beedrill     Bug  Poison   65      90       40       45
# 15  BeedrillMega Beedrill     Bug  Poison   65     150       40       15
# 39             Jigglypuff  Normal   Fairy  115      45       20       45
# 40             Wigglytuff  Normal   Fairy  140      70       45       85
#
#     Sp. Def  Speed  Generation  Legendary
# #
# 1        65     45           1      False
# 2        80     60           1      False
# ...

# %% [markdown]
# ### Using isnull() Function

# %%
test.loc[test['Type 2'].isnull()]
# Out:
#            Name  Type 1 Type 2   HP  Attack  Defense  Sp. Atk  Sp. Def  Speed  \
# #
# 4    Charmander    Fire    NaN   39      52       43       60       50     65
# 5    Charmeleon    Fire    NaN   58      64       58       80       65     80
# 7      Squirtle   Water    NaN   44      48       65       50       64     43
# 8     Wartortle   Water    NaN   59      63       80       65       80     58
# 9     Blastoise   Water    NaN   79      83      100       85      105     78
# ..          ...     ...    ...  ...     ...      ...      ...      ...    ...
# 705     Sliggoo  Dragon    NaN   68      75       53       83      113     60
# 706      Goodra  Dragon    NaN   90     100       70      110      150     80
# 712    Bergmite     Ice    NaN   55      69       85       32       35     28
# 713     Avalugg     Ice    NaN   95     117      184       44       46     28
# 716     Xerneas   Fairy    NaN  126     131       95      131       98     99
#
#      Generation  Legendary
# ...

# %% [markdown]
# ### Using notnull() Function

# %%
test.loc[test['Type 2'].notnull()]
# Out:
#                       Name   Type 1  Type 2  HP  Attack  Defense  Sp. Atk  \
# #
# 1                Bulbasaur    Grass  Poison  45      49       49       65
# 2                  Ivysaur    Grass  Poison  60      62       63       80
# 3                 Venusaur    Grass  Poison  80      82       83      100
# 3    VenusaurMega Venusaur    Grass  Poison  80     100      123      122
# 6                Charizard     Fire  Flying  78      84       78      109
# ..                     ...      ...     ...  ..     ...      ...      ...
# 719                Diancie     Rock   Fairy  50     100      150      100
# 719    DiancieMega Diancie     Rock   Fairy  50     160      110      160
# 720    HoopaHoopa Confined  Psychic   Ghost  80     110       60      150
# 720     HoopaHoopa Unbound  Psychic    Dark  80     160       60      170
# 721              Volcanion     Fire   Water  80     110      120      130
#
#      Sp. Def  Speed  Generation  Legendary
# #
# ...

# %% [markdown]
# ## Assigning Data

# %%
test['Demo']='Nothing'
test.Demo
# Out:
# #
# 1      Nothing
# 2      Nothing
# 3      Nothing
# 3      Nothing
# 4      Nothing
#         ...
# 719    Nothing
# 719    Nothing
# 720    Nothing
# 720    Nothing
# 721    Nothing
# Name: Demo, Length: 800, dtype: object

# %%
test.head()
# Out:
#                     Name Type 1  Type 2  HP  Attack  Defense  Sp. Atk  \
# #
# 1              Bulbasaur  Grass  Poison  45      49       49       65
# 2                Ivysaur  Grass  Poison  60      62       63       80
# 3               Venusaur  Grass  Poison  80      82       83      100
# 3  VenusaurMega Venusaur  Grass  Poison  80     100      123      122
# 4             Charmander   Fire     NaN  39      52       43       60
#
#    Sp. Def  Speed  Generation  Legendary     Demo
# #
# 1       65     45           1      False  Nothing
# 2       80     60           1      False  Nothing
# 3      100     80           1      False  Nothing
# 3      120     80           1      False  Nothing
# 4       50     65           1      False  Nothing

# %%
test['Demo 2'] = range(len(test),0,-1)
test['Demo 2']
# Out:
# #
# 1      800
# 2      799
# 3      798
# 3      797
# 4      796
#       ...
# 719      5
# 719      4
# 720      3
# 720      2
# 721      1
# Name: Demo 2, Length: 800, dtype: int64

# %%
test.head()
# Out:
#                     Name Type 1  Type 2  HP  Attack  Defense  Sp. Atk  \
# #
# 1              Bulbasaur  Grass  Poison  45      49       49       65
# 2                Ivysaur  Grass  Poison  60      62       63       80
# 3               Venusaur  Grass  Poison  80      82       83      100
# 3  VenusaurMega Venusaur  Grass  Poison  80     100      123      122
# 4             Charmander   Fire     NaN  39      52       43       60
#
#    Sp. Def  Speed  Generation  Legendary     Demo  Demo 2
# #
# 1       65     45           1      False  Nothing     800
# 2       80     60           1      False  Nothing     799
# 3      100     80           1      False  Nothing     798
# 3      120     80           1      False  Nothing     797
# 4       50     65           1      False  Nothing     796

# %% [markdown]
# # Class - 3

# %% [markdown]
# ## Summary functions
# #### This method generates a high-level summary of the attributes of the given column. It is type-aware, meaning that its output changes based on the data type of the input. The output above only makes sense for numerical data

# %%
test.HP.describe()
# Out:
# count    800.000000
# mean      69.258750
# std       25.534669
# min        1.000000
# 25%       50.000000
# 50%       65.000000
# 75%       80.000000
# max      255.000000
# Name: HP, dtype: float64

# %% [markdown]
# ### For String Data

# %%
test.Name.describe()
# Out:
# count           800
# unique          800
# top       Bulbasaur
# freq              1
# Name: Name, dtype: object

# %% [markdown]
# ### Mean

# %%
test.HP.mean()
# Out:
# 69.25875

# %% [markdown]
# ### Unique

# %%
test.Name.unique()
# Out:
# array(['Bulbasaur', 'Ivysaur', 'Venusaur', 'VenusaurMega Venusaur',
#        'Charmander', 'Charmeleon', 'Charizard',
#        'CharizardMega Charizard X', 'CharizardMega Charizard Y',
#        'Squirtle', 'Wartortle', 'Blastoise', 'BlastoiseMega Blastoise',
#        'Caterpie', 'Metapod', 'Butterfree', 'Weedle', 'Kakuna',
#        'Beedrill', 'BeedrillMega Beedrill', 'Pidgey', 'Pidgeotto',
#        'Pidgeot', 'PidgeotMega Pidgeot', 'Rattata', 'Raticate', 'Spearow',
#        'Fearow', 'Ekans', 'Arbok', 'Pikachu', 'Raichu', 'Sandshrew',
#        'Sandslash', 'Nidoran (Female)', 'Nidorina', 'Nidoqueen',
#        'Nidoran (Male)', 'Nidorino', 'Nidoking', 'Clefairy', 'Clefable',
#        'Vulpix', 'Ninetales', 'Jigglypuff', 'Wigglytuff', 'Zubat',
#        'Golbat', 'Oddish', 'Gloom', 'Vileplume', 'Paras', 'Parasect',
#        'Venonat', 'Venomoth', 'Diglett', 'Dugtrio', 'Meowth', 'Persian',
#        'Psyduck', 'Golduck', 'Mankey', 'Primeape', 'Growlithe',
# ...

# %% [markdown]
# ### Counting

# %%
test.HP.value_counts()
# Out:
# 60     67
# 50     63
# 70     57
# 65     46
# 80     43
#        ..
# 111     1
# 160     1
# 81      1
# 140     1
# 97      1
# Name: HP, Length: 94, dtype: int64

# %% [markdown]
# ## Map
# #### In data science we often have a need for creating new representations from existing data, or for transforming data from the format it is in now to the format that we want it to be in later. Maps are what handle this work, making them extremely important for getting your work done!
# #### The function you pass to map() should expect a single value from the Series (a point value, in the above example), and return a transformed version of that value. map() returns a new Series where all the values have been transformed by your function.

# %%
mean_value = test.HP.mean()
test.HP.map(lambda p: p - mean_value)
# Out:
# #
# 1     -24.25875
# 2      -9.25875
# 3      10.74125
# 3      10.74125
# 4     -30.25875
#          ...
# 719   -19.25875
# 719   -19.25875
# 720    10.74125
# 720    10.74125
# 721    10.74125
# Name: HP, Length: 800, dtype: float64

# %% [markdown]
# ### Apply
# #### apply() is the equivalent method if we want to transform a whole DataFrame by calling a custom method on each row.

# %%
def remean_points(row):
    row.HP = row.HP - mean_value
    return row

test.apply(remean_points, axis='columns')
# Out:
#                       Name   Type 1  Type 2        HP  Attack  Defense  \
# #
# 1                Bulbasaur    Grass  Poison -24.25875      49       49
# 2                  Ivysaur    Grass  Poison  -9.25875      62       63
# 3                 Venusaur    Grass  Poison  10.74125      82       83
# 3    VenusaurMega Venusaur    Grass  Poison  10.74125     100      123
# 4               Charmander     Fire     NaN -30.25875      52       43
# ..                     ...      ...     ...       ...     ...      ...
# 719                Diancie     Rock   Fairy -19.25875     100      150
# 719    DiancieMega Diancie     Rock   Fairy -19.25875     160      110
# 720    HoopaHoopa Confined  Psychic   Ghost  10.74125     110       60
# 720     HoopaHoopa Unbound  Psychic    Dark  10.74125     160       60
# 721              Volcanion     Fire   Water  10.74125     110      120
#
#      Sp. Atk  Sp. Def  Speed  Generation  Legendary     Demo  Demo 2
# #
# ...

# %% [markdown]
# ### Note that map() and apply() return new, transformed Series and DataFrames, respectively. They don't modify the original data they're called on

# %% [markdown]
# # Class - 4

# %% [markdown]
# ## Groupwise analysis

# %% [markdown]
# #### when outputting the result of a groupby, the order of the rows is dependent on the values in the index, not in the data

# %%
test = pd.read_csv('pokemon_data.csv', index_col=0)
test.groupby('HP').HP.count()
# Out:
# HP
# 1      1
# 10     1
# 20     6
# 25     2
# 28     1
#       ..
# 165    1
# 170    1
# 190    1
# 250    1
# 255    1
# Name: HP, Length: 94, dtype: int64

# %%
test.head()
# Out:
#                     Name Type 1  Type 2  HP  Attack  Defense  Sp. Atk  \
# #
# 1              Bulbasaur  Grass  Poison  45      49       49       65
# 2                Ivysaur  Grass  Poison  60      62       63       80
# 3               Venusaur  Grass  Poison  80      82       83      100
# 3  VenusaurMega Venusaur  Grass  Poison  80     100      123      122
# 4             Charmander   Fire     NaN  39      52       43       60
#
#    Sp. Def  Speed  Generation  Legendary
# #
# 1       65     45           1      False
# 2       80     60           1      False
# 3      100     80           1      False
# 3      120     80           1      False
# 4       50     65           1      False

# %%
test.groupby('HP').Attack.min()
# Out:
# HP
# 1      90
# 10     55
# 20     10
# 25     20
# 28     25
#        ..
# 165    75
# 170    90
# 190    33
# 250     5
# 255    10
# Name: Attack, Length: 94, dtype: int64

# %% [markdown]
# #### You can think of each group we generate as being a slice of our DataFrame containing only data with values that match. This DataFrame is accessible to us directly using the apply() method, and we can then manipulate the data in any way we see fit

# %%
test.groupby(['Type 1', 'Type 2']).apply(lambda df: df.loc[df.HP.idxmax()])
# Out:
#                                      0  Attack  Defense  Generation  HP  \
# Type 1 Type 2
# Bug    Electric Name        Galvantula     NaN      NaN         NaN NaN
#                 Type 1             Bug     NaN      NaN         NaN NaN
#                 Type 2        Electric     NaN      NaN         NaN NaN
#                 HP                  70     NaN      NaN         NaN NaN
#                 Attack              77     NaN      NaN         NaN NaN
# ...                                ...     ...      ...         ...  ..
# Water  Steel    Sp. Atk            111     NaN      NaN         NaN NaN
#                 Sp. Def            101     NaN      NaN         NaN NaN
#                 Speed               60     NaN      NaN         NaN NaN
#                 Generation           4     NaN      NaN         NaN NaN
#                 Legendary        False     NaN      NaN         NaN NaN
#
#                            Legendary Name  Sp. Atk  Sp. Def  Speed Type 1  \
# ...

# %% [markdown]
# #### Another groupby() method worth mentioning is agg(), which lets you run a bunch of different functions on your DataFrame simultaneously. For example, we can generate a simple statistical summary of the dataset as follows

# %%
test.groupby('Type 1').HP.agg([len,min,max])
# Out:
#           len  min  max
# Type 1
# Bug        69    1   86
# Dark       31   35  126
# Dragon     32   41  125
# Electric   44   20   90
# Fairy      17   35  126
# Fighting   27   30  144
# Fire       52   38  115
# Flying      4   40   85
# Ghost      32   20  150
# Grass      70   30  123
# Ground     32   10  115
# Ice        24   36  110
# Normal     98   30  255
# Poison     28   35  105
# Psychic    57   20  190
# Rock       44   30  123
# Steel      27   40  100
# Water     112   20  170

# %% [markdown]
# ## Multi-indexes

# %% [markdown]
# #### In all of the examples we've seen thus far we've been working with DataFrame or Series objects with a single-label index. groupby() is slightly different in the fact that, depending on the operation we run, it will sometimes result in what is called a multi-index.

# %%
Type = test.groupby(['Type 1', 'Type 2']).HP.agg([len])
Type
# Out:
#                  len
# Type 1 Type 2
# Bug    Electric    2
#        Fighting    2
#        Fire        2
#        Flying     14
#        Ghost       1
# ...              ...
# Water  Ice         3
#        Poison      3
#        Psychic     5
#        Rock        4
#        Steel       1
#
# [136 rows x 1 columns]

# %%
type(Type.index)
# Out:
# pandas.core.indexes.multi.MultiIndex

# %% [markdown]
# ### Reseting Index

# %%
Type = Type.reset_index()
Type
# Out:
#     Type 1    Type 2  len
# 0      Bug  Electric    2
# 1      Bug  Fighting    2
# 2      Bug      Fire    2
# 3      Bug    Flying   14
# 4      Bug     Ghost    1
# ..     ...       ...  ...
# 131  Water       Ice    3
# 132  Water    Poison    3
# 133  Water   Psychic    5
# 134  Water      Rock    4
# 135  Water     Steel    1
#
# [136 rows x 3 columns]

# %% [markdown]
# # Sorting

# %%
Type.sort_values(by='len')
# Out:
#        Type 1  Type 2  len
# 135     Water   Steel    1
# 27   Electric   Fairy    1
# 28   Electric    Fire    1
# 31   Electric   Grass    1
# 32   Electric     Ice    1
# ..        ...     ...  ...
# 130     Water  Ground   10
# 7         Bug  Poison   12
# 3         Bug  Flying   14
# 64      Grass  Poison   15
# 83     Normal  Flying   24
#
# [136 rows x 3 columns]

# %%
Type.sort_values(by='len', ascending=False)
# Out:
#        Type 1  Type 2  len
# 83     Normal  Flying   24
# 64      Grass  Poison   15
# 3         Bug  Flying   14
# 7         Bug  Poison   12
# 55      Ghost   Grass   10
# ..        ...     ...  ...
# 47       Fire    Rock    1
# 77        Ice   Ghost    1
# 41       Fire  Dragon    1
# 38   Fighting  Flying    1
# 135     Water   Steel    1
#
# [136 rows x 3 columns]

# %%
Type.sort_values(by=['Type 1', 'len'])
# Out:
#     Type 1    Type 2  len
# 4      Bug     Ghost    1
# 10     Bug     Water    1
# 0      Bug  Electric    2
# 1      Bug  Fighting    2
# 2      Bug      Fire    2
# ..     ...       ...  ...
# 134  Water      Rock    4
# 133  Water   Psychic    5
# 122  Water      Dark    6
# 127  Water    Flying    7
# 130  Water    Ground   10
#
# [136 rows x 3 columns]

# %% [markdown]
# # Class - 5

# %% [markdown]
# ## Dtypes

# %% [markdown]
# #### The data type for a column in a DataFrame or a Series is known as the dtype.

# %%
test.HP.dtypes
# Out:
# dtype('int64')

# %%
test.dtypes
# Out:
# Name          object
# Type 1        object
# Type 2        object
# HP             int64
# Attack         int64
# Defense        int64
# Sp. Atk        int64
# Sp. Def        int64
# Speed          int64
# Generation     int64
# Legendary       bool
# dtype: object

# %% [markdown]
# #### It's possible to convert a column of one type into another wherever such a conversion makes sense by using the astype() function

# %%
test.HP.astype('float64')
# Out:
# #
# 1      45.0
# 2      60.0
# 3      80.0
# 3      80.0
# 4      39.0
#        ...
# 719    50.0
# 719    50.0
# 720    80.0
# 720    80.0
# 721    80.0
# Name: HP, Length: 800, dtype: float64

# %% [markdown]
# ## Missing data
# #### Entries missing values are given the value NaN, short for "Not a Number". For technical reasons these NaN values are always of the float64 dtype.

# %%
test[pd.isnull(test['Type 2'])]
# Out:
#            Name  Type 1 Type 2   HP  Attack  Defense  Sp. Atk  Sp. Def  Speed  \
# #
# 4    Charmander    Fire    NaN   39      52       43       60       50     65
# 5    Charmeleon    Fire    NaN   58      64       58       80       65     80
# 7      Squirtle   Water    NaN   44      48       65       50       64     43
# 8     Wartortle   Water    NaN   59      63       80       65       80     58
# 9     Blastoise   Water    NaN   79      83      100       85      105     78
# ..          ...     ...    ...  ...     ...      ...      ...      ...    ...
# 705     Sliggoo  Dragon    NaN   68      75       53       83      113     60
# 706      Goodra  Dragon    NaN   90     100       70      110      150     80
# 712    Bergmite     Ice    NaN   55      69       85       32       35     28
# 713     Avalugg     Ice    NaN   95     117      184       44       46     28
# 716     Xerneas   Fairy    NaN  126     131       95      131       98     99
#
#      Generation  Legendary
# ...

# %% [markdown]
# #### Replacing missing values is a common operation. Pandas provides a really handy method for this problem: fillna(). fillna() provides a few different strategies for mitigating such data. For example, we can simply replace each NaN with an "Unknown"

# %%
test['Type 2'].fillna('unknown')
# Out:
# #
# 1       Poison
# 2       Poison
# 3       Poison
# 3       Poison
# 4      unknown
#         ...
# 719      Fairy
# 719      Fairy
# 720      Ghost
# 720       Dark
# 721      Water
# Name: Type 2, Length: 800, dtype: object

# %% [markdown]
# ### Replace Keyword

# %%
test['Type 2'].replace('Poison','Invalid')
# Out:
# #
# 1      Invalid
# 2      Invalid
# 3      Invalid
# 3      Invalid
# 4          NaN
#         ...
# 719      Fairy
# 719      Fairy
# 720      Ghost
# 720       Dark
# 721      Water
# Name: Type 2, Length: 800, dtype: object

# %% [markdown]
# # Class - 6

# %% [markdown]
# ## Renaming

# %%
test.rename(columns={'Type 2': 'Power'})
# Out:
#                       Name   Type 1   Power  HP  Attack  Defense  Sp. Atk  \
# #
# 1                Bulbasaur    Grass  Poison  45      49       49       65
# 2                  Ivysaur    Grass  Poison  60      62       63       80
# 3                 Venusaur    Grass  Poison  80      82       83      100
# 3    VenusaurMega Venusaur    Grass  Poison  80     100      123      122
# 4               Charmander     Fire     NaN  39      52       43       60
# ..                     ...      ...     ...  ..     ...      ...      ...
# 719                Diancie     Rock   Fairy  50     100      150      100
# 719    DiancieMega Diancie     Rock   Fairy  50     160      110      160
# 720    HoopaHoopa Confined  Psychic   Ghost  80     110       60      150
# 720     HoopaHoopa Unbound  Psychic    Dark  80     160       60      170
# 721              Volcanion     Fire   Water  80     110      120      130
#
#      Sp. Def  Speed  Generation  Legendary
# #
# ...

# %% [markdown]
# #### rename() lets you rename index or column values by specifying a index or column keyword parameter, respectively. It supports a variety of input formats, but usually a Python dictionary is the most convenient.

# %%
test.rename(index={1: 'First', 2: 'second'})
# Out:
#                          Name   Type 1  Type 2  HP  Attack  Defense  Sp. Atk  \
# #
# First               Bulbasaur    Grass  Poison  45      49       49       65
# second                Ivysaur    Grass  Poison  60      62       63       80
# 3                    Venusaur    Grass  Poison  80      82       83      100
# 3       VenusaurMega Venusaur    Grass  Poison  80     100      123      122
# 4                  Charmander     Fire     NaN  39      52       43       60
# ...                       ...      ...     ...  ..     ...      ...      ...
# 719                   Diancie     Rock   Fairy  50     100      150      100
# 719       DiancieMega Diancie     Rock   Fairy  50     160      110      160
# 720       HoopaHoopa Confined  Psychic   Ghost  80     110       60      150
# 720        HoopaHoopa Unbound  Psychic    Dark  80     160       60      170
# 721                 Volcanion     Fire   Water  80     110      120      130
#
# ...

# %% [markdown]
# #### You'll probably rename columns very often, but rename index values very rarely. For that, set_index() is usually more convenient. Both the row index and the column index can have their own name attribute. The complimentary rename_axis() method may be used to change these names

# %%
test.rename_axis('Col_Names', axis='columns').rename_axis('Row_Names', axis='rows')
# Out:
# Col_Names                   Name   Type 1  Type 2  HP  Attack  Defense  \
# Row_Names
# 1                      Bulbasaur    Grass  Poison  45      49       49
# 2                        Ivysaur    Grass  Poison  60      62       63
# 3                       Venusaur    Grass  Poison  80      82       83
# 3          VenusaurMega Venusaur    Grass  Poison  80     100      123
# 4                     Charmander     Fire     NaN  39      52       43
# ...                          ...      ...     ...  ..     ...      ...
# 719                      Diancie     Rock   Fairy  50     100      150
# 719          DiancieMega Diancie     Rock   Fairy  50     160      110
# 720          HoopaHoopa Confined  Psychic   Ghost  80     110       60
# 720           HoopaHoopa Unbound  Psychic    Dark  80     160       60
# 721                    Volcanion     Fire   Water  80     110      120
#
# Col_Names  Sp. Atk  Sp. Def  Speed  Generation  Legendary
# Row_Names
# ...

# %% [markdown]
# ## Combining
# #### When performing operations on a dataset, we will sometimes need to combine different DataFrames and/or Series in non-trivial ways. Pandas has three core methods for doing this. In order of increasing complexity, these are concat(), join(), and merge(). Most of what merge() can do can also be done more simply with join(), so we will omit it and focus on the first two functions here.
# #### The simplest combining method is concat(). Given a list of elements, this function will smush those elements together along an axis
# #### This is useful when we have data in different DataFrame or Series objects but having the same fields (columns). One example: the YouTube Videos dataset, which splits the data up based on country of origin (e.g. Canada and the UK, in this example). If we want to study multiple countries simultaneously, we can use concat() to smush them together

# %% [markdown]
# # The End
